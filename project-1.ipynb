# %%
import numpy as np
import pandas as pd
#from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt

#from sklearn.neighbors import NearestNeighbors

# %%
train_list = [ #adding the train samples
    np.loadtxt("/kaggle/input/datasetsbigfile/Datasets/Dataset 1/Train1.sample", delimiter = " ", dtype = np.int64),
    np.loadtxt("/kaggle/input/datasetsbigfile/Datasets/Dataset 2/Train2.sample", delimiter = " ", dtype = np.int64),
    np.loadtxt("/kaggle/input/datasetsbigfile/Datasets/Dataset 3/Train3.sample", delimiter = " ", dtype = np.int64),
    np.loadtxt("/kaggle/input/datasetsbigfile/Datasets/Dataset 4/Train4.sample", delimiter = " ", dtype = np.int64),
    np.loadtxt("/kaggle/input/datasetsbigfile/Datasets/Dataset 5/Train5.sample", delimiter = " ", dtype = np.int64),
    np.loadtxt("/kaggle/input/datasetsbigfile/Datasets/Dataset 6/Train6.sample", delimiter = " ", dtype = np.int64),
    np.loadtxt("/kaggle/input/datasetsbigfile/Datasets/Dataset 7/train7.sample", delimiter = " ", dtype = np.int64)
]

# %%
    #prac = [
     #   np.loadtxt("/kaggle/input/datasetsbigfile/Datasets/Dataset 1/Train1.sample", delimiter = " ", dtype = np.int64),
     #      ]

# %%
test_list = [ #adding the test samples
    np.loadtxt("/kaggle/input/datasetsbigfile/Datasets/Dataset 1/Test1.sample", delimiter = " ", dtype = np.int64),
    np.loadtxt("/kaggle/input/datasetsbigfile/Datasets/Dataset 2/Test2.sample", delimiter = " ", dtype = np.int64),
    np.loadtxt("/kaggle/input/datasetsbigfile/Datasets/Dataset 3/Test3.sample", delimiter = " ", dtype = np.int64),
    np.loadtxt("/kaggle/input/datasetsbigfile/Datasets/Dataset 4/Test4.sample", delimiter = " ", dtype = np.int64),
    np.loadtxt("/kaggle/input/datasetsbigfile/Datasets/Dataset 5/Test5.sample", delimiter = " ", dtype = np.int64),
    np.loadtxt("/kaggle/input/datasetsbigfile/Datasets/Dataset 6/Test6.sample", delimiter = " ", dtype = np.int64),
    np.loadtxt("/kaggle/input/datasetsbigfile/Datasets/Dataset 7/Test7.sample", delimiter = " ", dtype = np.int64)
]

# %%
X_trainlist = []

X_testlist = []

y_trainlist = []

y_testlist = []

# %%
for i in range(len(train_list)):
    train = train_list[i]
    cols = train.shape[1]
    train = train[:, 2:cols]
    train = train.astype(int)
    
    X_train = train[:,0:-4]
    y_train = train[:,-4:]
    #colon wipe
    test = test_list[i]
    cols = test.shape[1]
    test = test[:,2:cols]
    test = test.astype(int)
    
    X_test = test[:,0:-4]
    y_test = test[:,-4:]
    
    #shaping the model

# %%
X_finaltraining = np.concatenate(X_trainlist, axis = 0)
X_finaltest = np.concatenate(X_testlist, axis = 0)
y_finaltraining = np.concatenate(y_trainlist, axis = 0)
y_finaltest = np.concatenate(y_testlist, axis = 0)

print(X_finaltraining)
print(X_finaltest)
print(y_finaltraining)
print(y_finaltest)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[293], line 1
# ----> 1 X_finaltraining = np.concatenate(X_trainlist, axis = 0)
#       2 X_finaltest = np.concatenate(X_testlist, axis = 0)
#       3 y_finaltraining = np.concatenate(y_trainlist, axis = 0)
#
# File <__array_function__ internals>:200, in concatenate(*args, **kwargs)
#
# ValueError: need at least one array to concatenate

# %%
from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors=7)
neigh.fit(X_finaltraining,y_finaltraining)

# %%
#from sklearn.neighbors import KNeighborsClassifier
#from sklearn import svm
#knn = KNeighborsClassifier()
#clf = svm.SVC(kernel='rbf')
#clf.fit(X_finaltraining, y_finaltraining)
#knn.fit(X_finaltest, y_finaltest)
